# %% [markdown]
# # Earth Overshoot Day
#
# Dataset: Global Footprint Network
# https://overshoot.footprintnetwork.org/newsroom/country-overshoot-days/
#
# #### Earth Overshoot Day is the date would fall when the global population have consumed the resources to support one planet.
#
# #### A Country Overshoot Day is the date on which the Earth Overshoot Day would fall if all of humanity consumed like the people in that country
#
# Country overshoot days are published on 1 January of each year. It uses latest year of the most recent National Footprint and Biocapacity Accounts Edition. Therefore the 2024 country overshoot days are based on the 2023 edition.
#
# The 2023 edition provides results from 1961 to 2022.
# * 2020 - 2022 results based on a mix of actual data and preliminary estimates due to varying time lags in data reporting
# * Preliminary estiamtes are not final and less robust than the estimates up to 2020 - which are based on fully reported data sets
#
#
# Example calculation of Swiss Overshoot Day:
# - based on 2023 edition, ie datapoints for 2022
#
# * Ecological Footprint of Switzerland per person in 2022 - 3.74 gha (global hectares)
# * Global biocapacity in 2022 - 1.51 gha per person
# * (3.74/1.51) = 2.5 Earths to support humanity if everyone on the planet lived like the people in Switzerland
# * 2024 was a leap year: 366[days in 2024] * (1.51/3.74) = 148[days]
# * 148th day is 27 May
#
# Not all countries have an Overshoot Day - if a country's Ecological Footprint per person is smaller than the global biocapacity per person (1.5 gha). These countries are listed as 'None' and excluded from the table below.jup

# %% [markdown]
# ## Questions to explore:
#
# #### 1. Calculate the Country Overshoot Days 2024 to see that they match the published data
#
# #### 2. Overshoot days are calculated based on ecological footprint by consumption. How would this compare with by production?
# - eg does Sweden have a higher consumption than production, but China would be the other way round?
# - what would the overshoot be if it's an average of consumption and production?
#
# #### 3. Calculate number of countries with no overshoot
#
# #### 4. Plot a graph of dates-number of countries to see the spread of countries overshooting a lot to little.
# - Note, None values need to be on the right-hand side, assign as 1 Jan 2025?
# Or even calculate the number of bonus days?
#
# #### 5. What is the relationship of overshoot days with other factors in the Global Footprint Network dataset?
# - eg life expectency v overshoot
# - GDP v overshoot
# - air quality (from the exam project!) and overshoot?
#
# #### 6. Further investigation using previous data to monitor how Overshoot Days have been changing through the years. eg
# - Is the Earth Overshoot Day arriving earlier or later in the year?
# - Does it correlate with this graph on LinkedIn from 1971-2023?
# - https://www.linkedin.com/feed/update/urn:li:activity:7092413572202274816?updateEntityUrn=urn%3Ali%3Afs_feedUpdate%3A%28V2%2Curn%3Ali%3Aactivity%3A7092413572202274816%29
# - Which countries are overshooting earlier and later?
# - eg. According to LinkedIn network, Sweden's was 3 April in 2023 and 21 April in 2024

# %% [markdown]
# #### 1. Calculating a Country's Overshoot Day 2024

# %%
def CountryOvershootDay(country_footprint):
    from datetime import datetime

    global_footprint = 1.51
    day_num = int(366*(global_footprint/country_footprint))
    date = datetime.strptime("2022" + "-" + str(day_num), "%Y-%j").strftime("%Y-%m-%d")
    return date

# %%
CountryOvershootDay(3.74)
# Out:
# '2022-05-27'

# %% [markdown]
# From the "NFBA 2023 Public Data Package 1.0" Excel spreadsheet:
# - Filter the "Country Results (2022 estimate)" tab to export a csv with columns: name of country, Total biocapacity (gha per person), official Country Overshoot Day
# - Use CountryOvershootDay() to add Date as a new colum
# - Compare with Global Footprint's calculation

# %%
import pandas as pd

df = pd.read_csv("Filtered_Earth_Overshoot_Days_2024.csv")

df
# Out:
#                                Country Quality Score  SDGi Life Exectancy  \
# 0                          Afghanistan            3A  52.5             62
# 1                              Albania            3A  71.6             76
# 2                              Algeria            3A  71.5             76
# 3                               Angola            3A  50.9             62
# 4                  Antigua and Barbuda            2B   NaN             78
# ..                                 ...           ...   ...            ...
# 176  Venezuela, Bolivarian Republic of            3A  60.3             71
# 177                           Viet Nam            3A  72.8             74
# 178                              Yemen            3A  52.1             64
# 179                             Zambia            3A   NaN            NaN
# 180                           Zimbabwe            2A   NaN            NaN
#
#       HDI Per Capita GDP                     Region Income Group  \
# 0    0.48            NaN   Middle East/Central Asia           LI
# 1     0.8        $14,889               Other Europe           UM
# 2    0.75        $11,137                     Africa           UM
# 3    0.59         $6,304                     Africa           LM
# 4    0.79        $18,749  Central America/Caribbean           HI
# ..    ...            ...                        ...          ...
# 176  0.69            NaN              South America           UM
# 177   0.7        $11,032               Asia-Pacific           LM
# 178  0.46         $1,780   Middle East/Central Asia           LM
# 179   NaN            NaN                     Africa           LM
# 180   NaN            NaN                     Africa           LI
#
#     Population (millions)  Total Ecological Footprint (Production)  \
# 0                    40.8                                 0.679451
# 1                     2.9                                 1.626551
# 2                    45.4                                 1.769579
# 3                      35                                 0.598284
# 4                     0.1                                 1.508591
# ..                    ...                                      ...
# 176                  29.3                                 2.124106
# 177                    99                                 2.237806
# 178                  31.2                                 0.371747
# 179                  19.5                                 1.155055
# 180                  15.3                                 0.941797
#
#      Total Ecological Footprint (Consumption)  Total biocapacity   \
# 0                                    0.801465            0.513827
# 1                                    2.071238            1.176752
# 2                                    2.222968            0.663375
# 3                                    0.857846            1.588191
# 4                                    2.936735            0.917277
# ..                                        ...                 ...
# 176                                  2.109537            2.945992
# 177                                  2.432274            0.795070
# 178                                  0.613258            0.347502
# 179                                  1.213215            1.651920
# 180                                  1.085391            0.631495
#
#      Ecological (Deficit) or Reserve  Number of Earths required  \
# 0                               -0.3                        0.5
# 1                               -0.9                        1.4
# 2                               -1.6                        1.5
# 3                                0.7                        0.6
# 4                               -2.0                        1.9
# ..                               ...                        ...
# 176                              0.8                        1.4
# 177                             -1.6                        1.6
# 178                             -0.3                        0.4
# 179                              0.4                        0.8
# 180                             -0.5                        0.7
#
#      Number of Countries required Official Overshoot Day
# 0                             1.6                    NaN
# 1                             1.8     September 23, 2024
# 2                             3.4      September 4, 2024
# 3                             0.5                    NaN
# 4                             3.2           July 6, 2024
# ..                            ...                    ...
# 176                           0.7     September 18, 2024
# 177                           3.1        August 14, 2024
# 178                           1.8                    NaN
# 179                           0.7                    NaN
# 180                           1.7                    NaN
#
# [181 rows x 16 columns]

# %%
import pandas as pd
from datetime import datetime
from datetime import datetime

# Import filtered table from Global Footprint Network
df = pd.read_csv("Filtered_Earth_Overshoot_Days_2024.csv")
df = df.rename(columns = {"Total Ecological Footprint (Consumption)" : "footprint_consumption", 
                          "Total Ecological Footprint (Production)" : "footprint_production",
                          "Number of Earths required" : "num_earths",
                          "Official Overshoot Day" : "official_overshoot_day"
                          })

# country_footprint = total ecological footprint global hectares per person (consumption)

# Fuction to calculate overshoot day
def OvershootDayConsumption(footprint_consumption):
         global_footprint = 1.51 # 2024 figure
         day_num = int(366*(global_footprint/footprint_consumption))
        
        # accounting for countries using less than 1 year of resources
         if day_num > 366: # running into 2025
                 day_num -= 366 # leap year in 2024
                 if day_num > 365: # running into 2026
                         day_num -= 365
                         date = datetime.strptime("2026-" + str(day_num), "%Y-%j").strftime("%Y-%m-%d")                         
                 else:
                         date = datetime.strptime("2025-" + str(day_num), "%Y-%j").strftime("%Y-%m-%d")
         else:   
                date = datetime.strptime("2024-" + str(day_num), "%Y-%j").strftime("%Y-%m-%d")
         return date


# Apply function row-wise to calculate overshoot_day
df["overshoot_day_consumption"] = df["footprint_consumption"].apply(OvershootDayConsumption)

# Calculating difference between calculated overshoot days and official overshoot days
# Convert 'overshoot_day' column to datetime format for consistency
df['overshoot_day_consumption'] = pd.to_datetime(df['overshoot_day_consumption'])

# Convert 'official_overshoot_day' column to datetime format, handle NaN values
df['official_overshoot_day'] = pd.to_datetime(df['official_overshoot_day'], errors='coerce')

# Perform subtraction and extract the number of days
df['difference'] = (df['overshoot_day_consumption'] - df['official_overshoot_day']).dt.days

df
# Out:
#                                Country Quality Score  SDGi Life Exectancy  \
# 0                          Afghanistan            3A  52.5             62
# 1                              Albania            3A  71.6             76
# 2                              Algeria            3A  71.5             76
# 3                               Angola            3A  50.9             62
# 4                  Antigua and Barbuda            2B   NaN             78
# ..                                 ...           ...   ...            ...
# 176  Venezuela, Bolivarian Republic of            3A  60.3             71
# 177                           Viet Nam            3A  72.8             74
# 178                              Yemen            3A  52.1             64
# 179                             Zambia            3A   NaN            NaN
# 180                           Zimbabwe            2A   NaN            NaN
#
#       HDI Per Capita GDP                     Region Income Group  \
# 0    0.48            NaN   Middle East/Central Asia           LI
# 1     0.8        $14,889               Other Europe           UM
# 2    0.75        $11,137                     Africa           UM
# 3    0.59         $6,304                     Africa           LM
# 4    0.79        $18,749  Central America/Caribbean           HI
# ..    ...            ...                        ...          ...
# 176  0.69            NaN              South America           UM
# 177   0.7        $11,032               Asia-Pacific           LM
# 178  0.46         $1,780   Middle East/Central Asia           LM
# 179   NaN            NaN                     Africa           LM
# 180   NaN            NaN                     Africa           LI
#
#     Population (millions)  footprint_production  footprint_consumption  \
# 0                    40.8              0.679451               0.801465
# 1                     2.9              1.626551               2.071238
# 2                    45.4              1.769579               2.222968
# 3                      35              0.598284               0.857846
# 4                     0.1              1.508591               2.936735
# ..                    ...                   ...                    ...
# 176                  29.3              2.124106               2.109537
# 177                    99              2.237806               2.432274
# 178                  31.2              0.371747               0.613258
# 179                  19.5              1.155055               1.213215
# 180                  15.3              0.941797               1.085391
#
#      Total biocapacity   Ecological (Deficit) or Reserve  num_earths  \
# 0              0.513827                             -0.3         0.5
# 1              1.176752                             -0.9         1.4
# 2              0.663375                             -1.6         1.5
# 3              1.588191                              0.7         0.6
# 4              0.917277                             -2.0         1.9
# ..                  ...                              ...         ...
# 176            2.945992                              0.8         1.4
# 177            0.795070                             -1.6         1.6
# 178            0.347502                             -0.3         0.4
# 179            1.651920                              0.4         0.8
# 180            0.631495                             -0.5         0.7
#
#      Number of Countries required official_overshoot_day  \
# 0                             1.6                    NaT
# 1                             1.8             2024-09-23
# 2                             3.4             2024-09-04
# 3                             0.5                    NaT
# 4                             3.2             2024-07-06
# ..                            ...                    ...
# 176                           0.7             2024-09-18
# 177                           3.1             2024-08-14
# 178                           1.8                    NaT
# 179                           0.7                    NaT
# 180                           1.7                    NaT
#
#     overshoot_day_consumption  difference
# 0                  2025-11-19         NaN
# 1                  2024-09-22        -1.0
# 2                  2024-09-04         0.0
# 3                  2025-10-05         NaN
# 4                  2024-07-06         0.0
# ..                        ...         ...
# 176                2024-09-17        -1.0
# 177                2024-08-14         0.0
# 178                2026-06-19         NaN
# 179                2025-03-30         NaN
# 180                2025-05-23         NaN
#
# [181 rows x 18 columns]

# %%
df.groupby('difference').size()

# now corrected. 56 entries are the same, 70 are one day earlier due to longer decimal places
# original 1 decimal place columns resulted in a big difference in days - ranging from my calculations being 8 days too early or 11 days too late compared to the official days
# Out:
# difference
# -1.0    70
#  0.0    56
# dtype: int64

# %%
df[df.Country.str.contains("Switzerland")]
# Out:
#          Country Quality Score  SDGi Life Exectancy   HDI Per Capita GDP  \
# 156  Switzerland            3A  80.8             84  0.96            NaN
#
#            Region Income Group Population (millions)  footprint_production  \
# 156  Other Europe           HI                   8.8              2.064868
#
#      footprint_consumption  Total biocapacity   \
# 156               3.735964            1.126134
#
#      Ecological (Deficit) or Reserve  num_earths  \
# 156                             -2.6         2.5
#
#      Number of Countries required official_overshoot_day  \
# 156                           3.3             2024-05-27
#
#     overshoot_day_consumption  difference
# 156                2024-05-26        -1.0

# %% [markdown]
# #### 2. Overshoot days are calculated based on ecological footprint by consumption. How would this compare with by production?
# - eg does Sweden have a higher consumption than production, but China would be the other way round?
# - what would the overshoot be if it's an average of consumption and production?

# %%
# Function to calculate overshoot day by production
def OvershootDayProduction(footprint_production):
         global_footprint = 1.51 # 2024 figure
         day_num = int(366*(global_footprint/footprint_production))
        
        # accounting for countries using less than 1 year of resources
         if day_num > 366: # running into 2025
                 day_num -= 366 # leap year in 2024
                 if day_num > 365: # running into 2026
                         day_num -= 365
                         if day_num > 365: # running into 2027
                                 day_num -= 365
                                 if day_num > 365: #running into 2028
                                         day_num-= 365
                                         date = datetime.strptime("2028-" + str(day_num), "%Y-%j").strftime("%Y-%m-%d")                         
                                 else:
                                         date = datetime.strptime("2027-" + str(day_num), "%Y-%j").strftime("%Y-%m-%d")                         
                         else:
                                 date = datetime.strptime("2026-" + str(day_num), "%Y-%j").strftime("%Y-%m-%d")                         
                 else:
                         date = datetime.strptime("2025-" + str(day_num), "%Y-%j").strftime("%Y-%m-%d")
         else:   
                date = datetime.strptime("2024-" + str(day_num), "%Y-%j").strftime("%Y-%m-%d")
         return date


# Apply function row-wise to calculate overshoot_day
df["overshoot_day_production"] = df["footprint_production"].apply(OvershootDayProduction)


# Calculating difference between overshoot days by production and consumption

# Convert 'overshoot_day_production' column to datetime format for consistency
df['overshoot_day_production'] = pd.to_datetime(df['overshoot_day_production'])


# Perform subtraction and extract the number of days
df['diff_production_consumption'] = (df['overshoot_day_production'] - df['overshoot_day_consumption']).dt.days

df
# Out:
#                                Country Quality Score  SDGi Life Exectancy  \
# 0                          Afghanistan            3A  52.5             62
# 1                              Albania            3A  71.6             76
# 2                              Algeria            3A  71.5             76
# 3                               Angola            3A  50.9             62
# 4                  Antigua and Barbuda            2B   NaN             78
# ..                                 ...           ...   ...            ...
# 176  Venezuela, Bolivarian Republic of            3A  60.3             71
# 177                           Viet Nam            3A  72.8             74
# 178                              Yemen            3A  52.1             64
# 179                             Zambia            3A   NaN            NaN
# 180                           Zimbabwe            2A   NaN            NaN
#
#       HDI Per Capita GDP                     Region Income Group  \
# 0    0.48            NaN   Middle East/Central Asia           LI
# 1     0.8        $14,889               Other Europe           UM
# 2    0.75        $11,137                     Africa           UM
# 3    0.59         $6,304                     Africa           LM
# 4    0.79        $18,749  Central America/Caribbean           HI
# ..    ...            ...                        ...          ...
# 176  0.69            NaN              South America           UM
# 177   0.7        $11,032               Asia-Pacific           LM
# 178  0.46         $1,780   Middle East/Central Asia           LM
# 179   NaN            NaN                     Africa           LM
# 180   NaN            NaN                     Africa           LI
#
#     Population (millions)  footprint_production  footprint_consumption  \
# 0                    40.8              0.679451               0.801465
# 1                     2.9              1.626551               2.071238
# 2                    45.4              1.769579               2.222968
# 3                      35              0.598284               0.857846
# 4                     0.1              1.508591               2.936735
# ..                    ...                   ...                    ...
# 176                  29.3              2.124106               2.109537
# 177                    99              2.237806               2.432274
# 178                  31.2              0.371747               0.613258
# 179                  19.5              1.155055               1.213215
# 180                  15.3              0.941797               1.085391
#
#      Total biocapacity   Ecological (Deficit) or Reserve  num_earths  \
# 0              0.513827                             -0.3         0.5
# 1              1.176752                             -0.9         1.4
# 2              0.663375                             -1.6         1.5
# 3              1.588191                              0.7         0.6
# 4              0.917277                             -2.0         1.9
# ..                  ...                              ...         ...
# 176            2.945992                              0.8         1.4
# 177            0.795070                             -1.6         1.6
# 178            0.347502                             -0.3         0.4
# 179            1.651920                              0.4         0.8
# 180            0.631495                             -0.5         0.7
#
#      Number of Countries required official_overshoot_day  \
# 0                             1.6                    NaT
# 1                             1.8             2024-09-23
# 2                             3.4             2024-09-04
# 3                             0.5                    NaT
# 4                             3.2             2024-07-06
# ..                            ...                    ...
# 176                           0.7             2024-09-18
# 177                           3.1             2024-08-14
# 178                           1.8                    NaT
# 179                           0.7                    NaT
# 180                           1.7                    NaT
#
#     overshoot_day_consumption  difference overshoot_day_production  \
# 0                  2025-11-19         NaN               2026-03-23
# 1                  2024-09-22        -1.0               2024-12-04
# 2                  2024-09-04         0.0               2024-11-07
# 3                  2025-10-05         NaN               2026-07-11
# 4                  2024-07-06         0.0               2024-12-31
# ..                        ...         ...                      ...
# 176                2024-09-17        -1.0               2024-09-16
# 177                2024-08-14         0.0               2024-09-02
# 178                2026-06-19         NaN               2028-01-25
# 179                2025-03-30         NaN               2025-04-22
# 180                2025-05-23         NaN               2025-08-08
#
#      diff_production_consumption
# 0                            124
# 1                             73
# 2                             64
# 3                            279
# 4                            178
# ..                           ...
# 176                           -1
# 177                           19
# 178                          585
# 179                           23
# 180                           77
#
# [181 rows x 20 columns]

# %%
df[df.Country.str.contains("Korea")]
# Out:
#                                    Country Quality Score  SDGi Life Exectancy  \
# 88  Korea, Democratic People's Republic of            3A   NaN             73
# 89                      Korea, Republic of            3A  77.9             84
#
#      HDI Per Capita GDP        Region Income Group Population (millions)  \
# 88   NaN            NaN  Asia-Pacific           LI                    26
# 89  0.93        $45,438  Asia-Pacific           HI                  51.3
#
#     footprint_production  footprint_consumption  Total biocapacity   \
# 88              1.157012               1.198198            0.533428
# 89              4.608281               5.821430            0.646887
#
#     Ecological (Deficit) or Reserve  num_earths  Number of Countries required  \
# 88                             -0.7         0.8                           2.2
# 89                             -5.2         3.9                           9.0
#
#    official_overshoot_day overshoot_day_consumption  difference  \
# 88                    NaT                2025-04-05         NaN
# 89             2024-04-04                2024-04-03        -1.0
#
#    overshoot_day_production  diff_production_consumption
# 88               2025-04-21                           16
# 89               2024-04-28                           25

# %%
df[df.diff_production_consumption > 0]

# 122 produce more than they consume - assuming these are developing countries more reliant on manufacturing for export
# Out:
#                  Country Quality Score  SDGi Life Exectancy   HDI  \
# 0            Afghanistan            3A  52.5             62  0.48
# 1                Albania            3A  71.6             76   0.8
# 2                Algeria            3A  71.5             76  0.75
# 3                 Angola            3A  50.9             62  0.59
# 4    Antigua and Barbuda            2B   NaN             78  0.79
# ..                   ...           ...   ...            ...   ...
# 174           Uzbekistan            3A  69.9             71  0.73
# 177             Viet Nam            3A  72.8             74   0.7
# 178                Yemen            3A  52.1             64  0.46
# 179               Zambia            3A   NaN            NaN   NaN
# 180             Zimbabwe            2A   NaN            NaN   NaN
#
#     Per Capita GDP                     Region Income Group  \
# 0              NaN   Middle East/Central Asia           LI
# 1          $14,889               Other Europe           UM
# 2          $11,137                     Africa           UM
# 3           $6,304                     Africa           LM
# 4          $18,749  Central America/Caribbean           HI
# ..             ...                        ...          ...
# 174            NaN   Middle East/Central Asia           LM
# 177        $11,032               Asia-Pacific           LM
# 178         $1,780   Middle East/Central Asia           LM
# 179            NaN                     Africa           LM
# 180            NaN                     Africa           LI
#
#     Population (millions)  footprint_production  footprint_consumption  \
# 0                    40.8              0.679451               0.801465
# 1                     2.9              1.626551               2.071238
# 2                    45.4              1.769579               2.222968
# 3                      35              0.598284               0.857846
# 4                     0.1              1.508591               2.936735
# ..                    ...                   ...                    ...
# 174                  34.4              1.848731               2.107132
# 177                    99              2.237806               2.432274
# 178                  31.2              0.371747               0.613258
# 179                  19.5              1.155055               1.213215
# 180                  15.3              0.941797               1.085391
#
#      Total biocapacity   Ecological (Deficit) or Reserve  num_earths  \
# 0              0.513827                             -0.3         0.5
# 1              1.176752                             -0.9         1.4
# 2              0.663375                             -1.6         1.5
# 3              1.588191                              0.7         0.6
# 4              0.917277                             -2.0         1.9
# ..                  ...                              ...         ...
# 174            0.730074                             -1.4         1.4
# 177            0.795070                             -1.6         1.6
# 178            0.347502                             -0.3         0.4
# 179            1.651920                              0.4         0.8
# 180            0.631495                             -0.5         0.7
#
#      Number of Countries required official_overshoot_day  \
# 0                             1.6                    NaT
# 1                             1.8             2024-09-23
# 2                             3.4             2024-09-04
# 3                             0.5                    NaT
# 4                             3.2             2024-07-06
# ..                            ...                    ...
# 174                           2.9             2024-09-18
# 177                           3.1             2024-08-14
# 178                           1.8                    NaT
# 179                           0.7                    NaT
# 180                           1.7                    NaT
#
#     overshoot_day_consumption  difference overshoot_day_production  \
# 0                  2025-11-19         NaN               2026-03-23
# 1                  2024-09-22        -1.0               2024-12-04
# 2                  2024-09-04         0.0               2024-11-07
# 3                  2025-10-05         NaN               2026-07-11
# 4                  2024-07-06         0.0               2024-12-31
# ..                        ...         ...                      ...
# 174                2024-09-18         0.0               2024-10-24
# 177                2024-08-14         0.0               2024-09-02
# 178                2026-06-19         NaN               2028-01-25
# 179                2025-03-30         NaN               2025-04-22
# 180                2025-05-23         NaN               2025-08-08
#
#      diff_production_consumption
# 0                            124
# 1                             73
# 2                             64
# 3                            279
# 4                            178
# ..                           ...
# 174                           36
# 177                           19
# 178                          585
# 179                           23
# 180                           77
#
# [122 rows x 20 columns]

# %%
df[df.diff_production_consumption < 0].count()

# 55 consume more than they produce - assuming these are developed and wealthy countries with little manufacturing
# Out:
# Country                            55
# Quality Score                      55
# SDGi                               52
# Life Exectancy                     55
# HDI                                55
# Per Capita GDP                     52
# Region                             55
# Income Group                       55
# Population (millions)              55
# footprint_production               55
# footprint_consumption              55
# Total biocapacity                  55
# Ecological (Deficit) or Reserve    55
# num_earths                         55
# Number of Countries required       55
# official_overshoot_day             41
# overshoot_day_consumption          55
# difference                         41
# overshoot_day_production           55
# diff_production_consumption        55
# dtype: int64

# %% [markdown]
# #### 3. Countries with no overshoot days (by consumption)
#
# - How many are there?
# - Who are they?
# - When is their Overshoot Day?

# %%
df[df.footprint_consumption < 1.51]
# Out:
#                                     Country Quality Score  SDGi  \
# 0                               Afghanistan            3A  52.5
# 3                                    Angola            3A  50.9
# 11                               Bangladesh            3A  64.2
# 16                                    Benin            3A  51.2
# 24                             Burkina Faso            3A  54.5
# 25                                  Burundi            3A  54.1
# 26                               Cabo Verde            2B   NaN
# 27                                 Cambodia            2B  63.8
# 28                                 Cameroon            3A  55.5
# 30                 Central African Republic            3A  39.3
# 31                                     Chad            3A  41.3
# 36                                    Congo            3A  52.3
# 37            Congo, Democratic Republic of            3A    50
# 39                            C?te d'Ivoire            3A
# 49                                    Egypt            2B  68.7
# 52                                  Eritrea            2A   NaN
# 55                                 Ethiopia            3A    58
# 62                                   Gambia            3A  60.2
# 71                            Guinea-Bissau            3A   NaN
# 73                                    Haiti            3A  51.9
# 74                                 Honduras            2B  63.1
# 76                                    India            3A  60.3
# 85                                   Jordan            2A  69.4
# 87                                    Kenya            3A    61
# 88   Korea, Democratic People's Republic of            3A   NaN
# 95                                  Lesotho            2B  55.1
# 96                                  Liberia            2A  49.9
# 99                               Madagascar            3A  50.1
# 100                                  Malawi            3A  53.3
# 102                                    Mali            3A  54.1
# 111                              Mozambique            3A  53.6
# 112                                 Myanmar            3A  64.3
# 114                                   Nepal            3A  66.2
# 117                               Nicaragua            3A  67.1
# 118                                   Niger            3A  52.2
# 119                                 Nigeria            3A  54.2
# 122                                Pakistan            3A  59.3
# 124                        Papua New Guinea            2A  53.6
# 127                             Philippines            3A  66.6
# 136                                  Rwanda            3A  59.4
# 140                   Sao Tome and Principe            2B  59.4
# 142                                 Senegal            2A  58.7
# 144                            Sierra Leone            3A    53
# 149                                 Somalia            3A  45.6
# 153                                   Sudan            3A  49.6
# 157                    Syrian Arab Republic            3A  57.4
# 158                              Tajikistan            2A  69.7
# 159            Tanzania, United Republic of            3A  57.4
# 161                             Timor-Leste            2A     0
# 162                                    Togo            3A   NaN
# 165                                 Tunisia            2A  70.7
# 168                                  Uganda            3A  54.9
# 178                                   Yemen            3A  52.1
# 179                                  Zambia            3A   NaN
# 180                                Zimbabwe            2A   NaN
#
#     Life Exectancy   HDI Per Capita GDP                     Region  \
# 0               62  0.48            NaN   Middle East/Central Asia
# 3               62  0.59         $6,304                     Africa
# 11              72  0.66         $5,681               Asia-Pacific
# 16              60  0.53         $3,543                     Africa
# 24              59  0.45         $2,281                     Africa
# 25              62  0.43           $733                     Africa
# 26              74  0.66         $6,629                     Africa
# 27              70  0.59         $4,705               Asia-Pacific
# 28              60  0.58         $3,767                     Africa
# 30              54   0.4           $944                     Africa
# 31              53  0.39         $1,460                     Africa
# 36              64  0.57         $3,921                     Africa
# 37              59  0.48         $1,127                     Africa
# 39                                                          Africa
# 49              70  0.73        $12,786                     Africa
# 52              67  0.49         $1,800                     Africa
# 55              65   0.5         $2,918                     Africa
# 62              62   0.5         $2,266                     Africa
# 71              60  0.48         $2,384                     Africa
# 73              63  0.54         $2,731  Central America/Caribbean
# 74              70  0.62         $5,773  Central America/Caribbean
# 76              67  0.63         $7,159               Asia-Pacific
# 85              74  0.72        $10,159   Middle East/Central Asia
# 87              61  0.58         $5,192                     Africa
# 88              73   NaN            NaN               Asia-Pacific
# 95              53  0.51         $2,599                     Africa
# 96              61  0.48         $1,524                     Africa
# 99              64   0.5         $1,523                     Africa
# 100             63  0.51         $1,373                     Africa
# 102             59  0.43         $2,206                     Africa
# 111             59  0.45         $1,232                     Africa
# 112             66  0.59         $4,090               Asia-Pacific
# 114             68   0.6         $3,921               Asia-Pacific
# 117             74  0.67         $6,056  Central America/Caribbean
# 118             62   0.4         $1,229                     Africa
# 119             53  0.54         $5,013                     Africa
# 122             66  0.54         $5,542               Asia-Pacific
# 124             65  0.56         $3,682               Asia-Pacific
# 127             69   0.7         $8,768               Asia-Pacific
# 136             66  0.53         $2,405                     Africa
# 140             68  0.62         $4,010                     Africa
# 142             67  0.51         $3,505                     Africa
# 144             60  0.48         $1,677                     Africa
# 149             55               $1,132                     Africa
# 153             65  0.51         $3,804                     Africa
# 157             72  0.58            NaN   Middle East/Central Asia
# 158             72  0.69         $3,966   Middle East/Central Asia
# 159             66  0.55         $2,876                     Africa
# 161             68  0.61         $2,860               Asia-Pacific
# 162             62  0.54         $2,226                     Africa
# 165             74  0.73        $10,535                     Africa
# 168             63  0.53            NaN                     Africa
# 178             64  0.46         $1,780   Middle East/Central Asia
# 179            NaN   NaN            NaN                     Africa
# 180            NaN   NaN            NaN                     Africa
#
#     Income Group Population (millions)  footprint_production  \
# 0             LI                  40.8              0.679451
# 3             LM                    35              0.598284
# 11            LI                 167.9              0.473200
# 16            LI                  12.8              0.952364
# 24            LI                  22.1              0.831123
# 25            LI                  12.6              0.568274
# 26            LM                   0.6              1.414816
# 27            LI                  17.2              1.163795
# 28            LM                  27.9              1.005492
# 30            LI                     5              1.148875
# 31            LI                  17.4              1.381630
# 36            LM                   5.8              0.935833
# 37            LI                  95.2              0.638072
# 39            LM                  27.7              0.949721
# 49            LM                 106.2              1.052604
# 52            LI                   3.7              0.650835
# 55            LI                 120.8              0.815772
# 62            LI                   2.6              0.469835
# 71            LI                   2.1              1.259278
# 73            LI                  11.7              0.375913
# 74            LM                  10.2              1.288882
# 76            LM              1,406.60              1.011949
# 85            UM                  10.3              0.825251
# 87            LI                  56.2              0.757845
# 88            LI                    26              1.157012
# 95            LM                   2.2              1.255344
# 96            LI                   5.3              1.113670
# 99            LI                  29.2              0.743493
# 100           LI                  20.2              0.715373
# 102           LI                  21.5              1.072262
# 111           LI                  33.1              0.625737
# 112           LI                  55.2              1.156774
# 114           LI                  30.2              0.666924
# 117           LM                   6.8              1.863353
# 118           LI                  26.1              1.269969
# 119           LM                 216.7              0.740836
# 122           LM                 229.5              0.700499
# 124           LM                   9.3              1.629152
# 127           LM                 112.5              0.943528
# 136           LI                  13.6              0.464975
# 140           LM                   0.2              1.000422
# 142           LM                  17.7              1.219713
# 144           LI                   8.3              0.923239
# 149           LI                  16.8              0.772068
# 153           LM                    46              1.186211
# 157           LM                  19.4              0.937940
# 158           LI                    10              0.927721
# 159           LI                  63.3              0.980268
# 161           LM                   1.4              0.407715
# 162           LI                   8.7              0.744717
# 165           UM                    12              1.436133
# 168           LI                  48.4              0.980741
# 178           LM                  31.2              0.371747
# 179           LM                  19.5              1.155055
# 180           LI                  15.3              0.941797
#
#      footprint_consumption  Total biocapacity   \
# 0                 0.801465            0.513827
# 3                 0.857846            1.588191
# 11                0.670725            0.247818
# 16                1.110590            0.633464
# 24                0.897787            0.694622
# 25                0.593606            0.356307
# 26                1.162179            0.437321
# 27                1.339451            1.011947
# 28                1.044024            1.426699
# 30                1.116874            6.411714
# 31                1.374624            1.442214
# 36                1.118348            7.831302
# 37                0.685390            1.846246
# 39                0.884764            1.106373
# 49                1.453028            0.313084
# 52                0.724095            1.949389
# 55                0.840928            0.449048
# 62                0.853872            0.453522
# 71                1.207245            2.243595
# 73                0.591012            0.235700
# 74                1.347079            1.651120
# 76                1.037628            0.342228
# 85                1.303853            0.214335
# 87                0.881302            0.462796
# 88                1.198198            0.533428
# 95                1.151056            0.723708
# 96                1.242562            2.731746
# 99                0.794029            1.978754
# 100               0.724282            0.576488
# 102               1.000774            1.368690
# 111               0.771230            1.385576
# 112               1.114220            1.362234
# 114               0.900456            0.390029
# 117               1.493572            2.310418
# 118               1.350308            1.074302
# 119               0.801335            0.446354
# 122               0.729967            0.361549
# 124               1.154843            2.900181
# 127               1.179382            0.402746
# 136               0.554030            0.243489
# 140               1.051870            0.700091
# 142               1.219524            1.000163
# 144               1.046276            0.921573
# 149               0.891390            0.712411
# 153               1.141856            1.131661
# 157               0.997263            0.599875
# 158               1.060972            0.447701
# 159               0.926305            0.799756
# 161               0.567020            1.591162
# 162               0.893112            0.553858
# 165               1.361352            0.716018
# 168               0.977960            0.478873
# 178               0.613258            0.347502
# 179               1.213215            1.651920
# 180               1.085391            0.631495
#
#      Ecological (Deficit) or Reserve  num_earths  \
# 0                               -0.3         0.5
# 3                                0.7         0.6
# 11                              -0.4         0.4
# 16                              -0.5         0.7
# 24                              -0.2         0.6
# 25                              -0.2         0.4
# 26                              -0.7         0.8
# 27                              -0.3         0.9
# 28                               0.4         0.7
# 30                               5.3         0.7
# 31                               0.1         0.9
# 36                               6.7         0.7
# 37                               1.2         0.5
# 39                               0.2         0.6
# 49                              -1.1         1.0
# 52                               1.2         0.5
# 55                              -0.4         0.6
# 62                              -0.4         0.6
# 71                               1.0         0.8
# 73                              -0.4         0.4
# 74                               0.3         0.9
# 76                              -0.7         0.7
# 85                              -1.1         0.9
# 87                              -0.4         0.6
# 88                              -0.7         0.8
# 95                              -0.4         0.8
# 96                               1.5         0.8
# 99                               1.2         0.5
# 100                             -0.1         0.5
# 102                              0.4         0.7
# 111                              0.6         0.5
# 112                              0.2         0.7
# 114                             -0.5         0.6
# 117                              0.8         1.0
# 118                             -0.3         0.9
# 119                             -0.4         0.5
# 122                             -0.4         0.5
# 124                              1.7         0.8
# 127                             -0.8         0.8
# 136                             -0.3         0.4
# 140                             -0.4         0.7
# 142                             -0.2         0.8
# 144                             -0.1         0.7
# 149                             -0.2         0.6
# 153                              0.0         0.8
# 157                             -0.4         0.7
# 158                             -0.6         0.7
# 159                             -0.1         0.6
# 161                              1.0         0.4
# 162                             -0.3         0.6
# 165                             -0.6         0.9
# 168                             -0.5         0.6
# 178                             -0.3         0.4
# 179                              0.4         0.8
# 180                             -0.5         0.7
#
#      Number of Countries required official_overshoot_day  \
# 0                             1.6                    NaT
# 3                             0.5                    NaT
# 11                            2.7                    NaT
# 16                            1.8                    NaT
# 24                            1.3                    NaT
# 25                            1.7                    NaT
# 26                            2.7                    NaT
# 27                            1.3                    NaT
# 28                            0.7                    NaT
# 30                            0.2                    NaT
# 31                            1.0                    NaT
# 36                            0.1                    NaT
# 37                            0.4                    NaT
# 39                            0.8                    NaT
# 49                            4.6                    NaT
# 52                            0.4                    NaT
# 55                            1.9                    NaT
# 62                            1.9                    NaT
# 71                            0.5                    NaT
# 73                            2.5                    NaT
# 74                            0.8                    NaT
# 76                            3.0                    NaT
# 85                            6.1                    NaT
# 87                            1.9                    NaT
# 88                            2.2                    NaT
# 95                            1.6                    NaT
# 96                            0.5                    NaT
# 99                            0.4                    NaT
# 100                           1.3                    NaT
# 102                           0.7                    NaT
# 111                           0.6                    NaT
# 112                           0.8                    NaT
# 114                           2.3                    NaT
# 117                           0.6                    NaT
# 118                           1.3                    NaT
# 119                           1.8                    NaT
# 122                           2.0                    NaT
# 124                           0.4                    NaT
# 127                           2.9                    NaT
# 136                           2.3                    NaT
# 140                           1.5                    NaT
# 142                           1.2                    NaT
# 144                           1.1                    NaT
# 149                           1.3                    NaT
# 153                           1.0                    NaT
# 157                           1.7                    NaT
# 158                           2.4                    NaT
# 159                           1.2                    NaT
# 161                           0.4                    NaT
# 162                           1.6                    NaT
# 165                           1.9                    NaT
# 168                           2.0                    NaT
# 178                           1.8                    NaT
# 179                           0.7                    NaT
# 180                           1.7                    NaT
#
#     overshoot_day_consumption  difference overshoot_day_production  \
# 0                  2025-11-19         NaN               2026-03-23
# 3                  2025-10-05         NaN               2026-07-11
# 11                 2026-04-02         NaN               2027-03-12
# 16                 2025-05-11         NaN               2025-08-02
# 24                 2025-09-06         NaN               2025-10-25
# 25                 2026-07-19         NaN               2026-08-29
# 26                 2025-04-19         NaN               2025-01-24
# 27                 2025-02-15         NaN               2025-04-18
# 28                 2025-06-12         NaN               2025-07-02
# 30                 2025-05-08         NaN               2025-04-25
# 31                 2025-02-05         NaN               2025-02-03
# 36                 2025-05-08         NaN               2025-08-12
# 37                 2026-03-16         NaN               2026-05-15
# 39                 2025-09-15         NaN               2025-08-03
# 49                 2025-01-14         NaN               2025-06-08
# 52                 2026-02-01         NaN               2026-04-28
# 55                 2025-10-18         NaN               2025-11-07
# 62                 2025-10-08         NaN               2027-03-21
# 71                 2025-04-01         NaN               2025-03-13
# 73                 2026-07-23         NaN               2028-01-09
# 74                 2025-02-13         NaN               2025-03-03
# 76                 2025-06-15         NaN               2025-06-29
# 85                 2025-02-26         NaN               2025-10-30
# 87                 2025-09-18         NaN               2025-12-29
# 88                 2025-04-05         NaN               2025-04-21
# 95                 2025-04-24         NaN               2025-03-15
# 96                 2025-03-19         NaN               2025-05-10
# 99                 2025-11-26         NaN               2026-01-12
# 100                2026-02-01         NaN               2026-02-10
# 102                2025-07-05         NaN               2025-05-29
# 111                2025-12-16         NaN               2026-06-01
# 112                2025-05-10         NaN               2025-04-21
# 114                2025-09-04         NaN               2026-04-07
# 117                2025-01-04         NaN               2024-10-22
# 118                2025-02-12         NaN               2025-03-10
# 119                2025-11-19         NaN               2026-01-14
# 122                2026-01-26         NaN               2026-02-26
# 124                2025-04-22         NaN               2024-12-04
# 127                2025-04-12         NaN               2025-08-07
# 136                2026-09-23         NaN               2027-04-02
# 140                2025-06-08         NaN               2025-07-05
# 142                2025-03-28         NaN               2025-03-28
# 144                2025-06-11         NaN               2025-08-20
# 149                2025-09-10         NaN               2025-12-15
# 153                2025-04-28         NaN               2025-04-09
# 157                2025-07-07         NaN               2025-08-11
# 158                2025-06-03         NaN               2025-08-17
# 159                2025-08-18         NaN               2025-07-16
# 161                2026-08-31         NaN               2027-09-16
# 162                2025-09-09         NaN               2026-01-11
# 165                2025-02-08         NaN               2025-01-18
# 168                2025-07-18         NaN               2025-07-16
# 178                2026-06-19         NaN               2028-01-25
# 179                2025-03-30         NaN               2025-04-22
# 180                2025-05-23         NaN               2025-08-08
#
#      diff_production_consumption
# 0                            124
# 3                            279
# 11                           344
# 16                            83
# 24                            49
# 25                            41
# 26                           -85
# 27                            62
# 28                            20
# 30                           -13
# 31                            -2
# 36                            96
# 37                            60
# 39                           -43
# 49                           145
# 52                            86
# 55                            20
# 62                           529
# 71                           -19
# 73                           535
# 74                            18
# 76                            14
# 85                           246
# 87                           102
# 88                            16
# 95                           -40
# 96                            52
# 99                            47
# 100                            9
# 102                          -37
# 111                          167
# 112                          -19
# 114                          215
# 117                          -74
# 118                           26
# 119                           56
# 122                           31
# 124                         -139
# 127                          117
# 136                          191
# 140                           27
# 142                            0
# 144                           70
# 149                           96
# 153                          -19
# 157                           35
# 158                           75
# 159                          -33
# 161                          381
# 162                          124
# 165                          -21
# 168                           -2
# 178                          585
# 179                           23
# 180                           77

# %%
df[df.footprint_consumption < 1.51].count()

# 55 countries with overshoot day in 2025 and 2026
# Out:
# Country                            55
# Quality Score                      55
# SDGi                               48
# Life Exectancy                     53
# HDI                                52
# Per Capita GDP                     49
# Region                             55
# Income Group                       55
# Population (millions)              55
# footprint_production               55
# footprint_consumption              55
# Total biocapacity                  55
# Ecological (Deficit) or Reserve    55
# num_earths                         55
# Number of Countries required       55
# official_overshoot_day              0
# overshoot_day_consumption          55
# difference                          0
# overshoot_day_production           55
# diff_production_consumption        55
# dtype: int64

# %%
df2026 = df[df.overshoot_day_consumption > '2026']
df2026
# Out:
#                            Country Quality Score  SDGi Life Exectancy   HDI  \
# 11                      Bangladesh            3A  64.2             72  0.66
# 25                         Burundi            3A  54.1             62  0.43
# 37   Congo, Democratic Republic of            3A    50             59  0.48
# 52                         Eritrea            2A   NaN             67  0.49
# 73                           Haiti            3A  51.9             63  0.54
# 100                         Malawi            3A  53.3             63  0.51
# 122                       Pakistan            3A  59.3             66  0.54
# 136                         Rwanda            3A  59.4             66  0.53
# 161                    Timor-Leste            2A     0             68  0.61
# 178                          Yemen            3A  52.1             64  0.46
#
#     Per Capita GDP                     Region Income Group  \
# 11          $5,681               Asia-Pacific           LI
# 25            $733                     Africa           LI
# 37          $1,127                     Africa           LI
# 52          $1,800                     Africa           LI
# 73          $2,731  Central America/Caribbean           LI
# 100         $1,373                     Africa           LI
# 122         $5,542               Asia-Pacific           LM
# 136         $2,405                     Africa           LI
# 161         $2,860               Asia-Pacific           LM
# 178         $1,780   Middle East/Central Asia           LM
#
#     Population (millions)  footprint_production  footprint_consumption  \
# 11                  167.9              0.473200               0.670725
# 25                   12.6              0.568274               0.593606
# 37                   95.2              0.638072               0.685390
# 52                    3.7              0.650835               0.724095
# 73                   11.7              0.375913               0.591012
# 100                  20.2              0.715373               0.724282
# 122                 229.5              0.700499               0.729967
# 136                  13.6              0.464975               0.554030
# 161                   1.4              0.407715               0.567020
# 178                  31.2              0.371747               0.613258
#
#      Total biocapacity   Ecological (Deficit) or Reserve  num_earths  \
# 11             0.247818                             -0.4         0.4
# 25             0.356307                             -0.2         0.4
# 37             1.846246                              1.2         0.5
# 52             1.949389                              1.2         0.5
# 73             0.235700                             -0.4         0.4
# 100            0.576488                             -0.1         0.5
# 122            0.361549                             -0.4         0.5
# 136            0.243489                             -0.3         0.4
# 161            1.591162                              1.0         0.4
# 178            0.347502                             -0.3         0.4
#
#      Number of Countries required official_overshoot_day  \
# 11                            2.7                    NaT
# 25                            1.7                    NaT
# 37                            0.4                    NaT
# 52                            0.4                    NaT
# 73                            2.5                    NaT
# 100                           1.3                    NaT
# 122                           2.0                    NaT
# 136                           2.3                    NaT
# 161                           0.4                    NaT
# 178                           1.8                    NaT
#
#     overshoot_day_consumption  difference overshoot_day_production  \
# 11                 2026-04-02         NaN               2027-03-12
# 25                 2026-07-19         NaN               2026-08-29
# 37                 2026-03-16         NaN               2026-05-15
# 52                 2026-02-01         NaN               2026-04-28
# 73                 2026-07-23         NaN               2028-01-09
# 100                2026-02-01         NaN               2026-02-10
# 122                2026-01-26         NaN               2026-02-26
# 136                2026-09-23         NaN               2027-04-02
# 161                2026-08-31         NaN               2027-09-16
# 178                2026-06-19         NaN               2028-01-25
#
#      diff_production_consumption
# 11                           344
# 25                            41
# 37                            60
# 52                            86
# 73                           535
# 100                            9
# 122                           31
# 136                          191
# 161                          381
# 178                          585

# %%
df2026.count()

# 10 countries with an overshoot day in 2026
# Out:
# Country                            10
# Quality Score                      10
# SDGi                                9
# Life Exectancy                     10
# HDI                                10
# Per Capita GDP                     10
# Region                             10
# Income Group                       10
# Population (millions)              10
# footprint_production               10
# footprint_consumption              10
# Total biocapacity                  10
# Ecological (Deficit) or Reserve    10
# num_earths                         10
# Number of Countries required       10
# official_overshoot_day              0
# overshoot_day_consumption          10
# difference                          0
# overshoot_day_production           10
# diff_production_consumption        10
# dtype: int64

# %%
df2026.sort_values('overshoot_day_consumption')
# Out:
#                            Country Quality Score  SDGi Life Exectancy   HDI  \
# 122                       Pakistan            3A  59.3             66  0.54
# 52                         Eritrea            2A   NaN             67  0.49
# 100                         Malawi            3A  53.3             63  0.51
# 37   Congo, Democratic Republic of            3A    50             59  0.48
# 11                      Bangladesh            3A  64.2             72  0.66
# 178                          Yemen            3A  52.1             64  0.46
# 25                         Burundi            3A  54.1             62  0.43
# 73                           Haiti            3A  51.9             63  0.54
# 161                    Timor-Leste            2A     0             68  0.61
# 136                         Rwanda            3A  59.4             66  0.53
#
#     Per Capita GDP                     Region Income Group  \
# 122         $5,542               Asia-Pacific           LM
# 52          $1,800                     Africa           LI
# 100         $1,373                     Africa           LI
# 37          $1,127                     Africa           LI
# 11          $5,681               Asia-Pacific           LI
# 178         $1,780   Middle East/Central Asia           LM
# 25            $733                     Africa           LI
# 73          $2,731  Central America/Caribbean           LI
# 161         $2,860               Asia-Pacific           LM
# 136         $2,405                     Africa           LI
#
#     Population (millions)  footprint_production  footprint_consumption  \
# 122                 229.5              0.700499               0.729967
# 52                    3.7              0.650835               0.724095
# 100                  20.2              0.715373               0.724282
# 37                   95.2              0.638072               0.685390
# 11                  167.9              0.473200               0.670725
# 178                  31.2              0.371747               0.613258
# 25                   12.6              0.568274               0.593606
# 73                   11.7              0.375913               0.591012
# 161                   1.4              0.407715               0.567020
# 136                  13.6              0.464975               0.554030
#
#      Total biocapacity   Ecological (Deficit) or Reserve  num_earths  \
# 122            0.361549                             -0.4         0.5
# 52             1.949389                              1.2         0.5
# 100            0.576488                             -0.1         0.5
# 37             1.846246                              1.2         0.5
# 11             0.247818                             -0.4         0.4
# 178            0.347502                             -0.3         0.4
# 25             0.356307                             -0.2         0.4
# 73             0.235700                             -0.4         0.4
# 161            1.591162                              1.0         0.4
# 136            0.243489                             -0.3         0.4
#
#      Number of Countries required official_overshoot_day  \
# 122                           2.0                    NaT
# 52                            0.4                    NaT
# 100                           1.3                    NaT
# 37                            0.4                    NaT
# 11                            2.7                    NaT
# 178                           1.8                    NaT
# 25                            1.7                    NaT
# 73                            2.5                    NaT
# 161                           0.4                    NaT
# 136                           2.3                    NaT
#
#     overshoot_day_consumption  difference overshoot_day_production  \
# 122                2026-01-26         NaN               2026-02-26
# 52                 2026-02-01         NaN               2026-04-28
# 100                2026-02-01         NaN               2026-02-10
# 37                 2026-03-16         NaN               2026-05-15
# 11                 2026-04-02         NaN               2027-03-12
# 178                2026-06-19         NaN               2028-01-25
# 25                 2026-07-19         NaN               2026-08-29
# 73                 2026-07-23         NaN               2028-01-09
# 161                2026-08-31         NaN               2027-09-16
# 136                2026-09-23         NaN               2027-04-02
#
#      diff_production_consumption
# 122                           31
# 52                            86
# 100                            9
# 37                            60
# 11                           344
# 178                          585
# 25                            41
# 73                           535
# 161                          381
# 136                          191

# %% [markdown]
# #### 4. Plot a graph of Overshoot Dates-number of countries
# - See the spread of countries overshooting a lot to little.
# - Note: None values need to be on the right-hand side, assign as 1 Jan 2025?
# - Or even calculate the number of bonus days?
# - colour coordinate based on continent

# %%
# number of regions = 7

df['Region'].unique()
# Out:
# array(['Middle East/Central Asia', 'Other Europe', 'Africa',
#        'Central America/Caribbean', 'South America', 'Asia-Pacific',
#        'EU-27', 'North America'], dtype=object)

# %%
# Graph of Overshoot Days by Consumption (similar to Offical Overshoot Days)

# %matplotlib
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.ticker import MultipleLocator
import mplcursors


# Colourmap for the regions
region_colours = {
    'North America' : 'mediumseagreen',
    'Central America/Caribbean' : 'lightseagreen',
    'South America' : 'teal',
    'EU-27' : 'mediumblue',
    'Other Europe' : 'cornflowerblue',    
    'Africa' : 'maroon',
    'Middle East/Central Asia' : 'red',
    'Asia-Pacific' : 'orange'
}


# Create a figure and axis
fig, ax = plt.subplots(figsize=(18,6))

# Create a separate bar plot for each region:
for region, color in region_colours.items():
    region_data = df[df['Region'] == region]
    plt.bar(region_data['overshoot_day_consumption'], region_data['num_earths'], color=color, 
            label=f"{region} - Overshoot Day: {region_data['overshoot_day_consumption'].mean().strftime('%d %B %Y')}")
    

# Titles and labels
ax.set_title("Country Overshoot Days (by Consumption) and Number of Earths")
ax.set_xlabel("Country Overshoot Day")
ax.set_ylabel("Number of Earths")


# Format x-axis
# Format x-axis ticks as months
ax.xaxis.set_minor_formatter(mdates.DateFormatter('%b'))

# Set x-axis tick labels to display every 2 months
ax.xaxis.set_minor_locator(mdates.MonthLocator(interval=2))

# Add ticks to indicate year changes
ax.xaxis.set_major_locator(mdates.YearLocator())

# Display minor ticks as year labels
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))

# Adjust position of year lables to be below month labels
ax.tick_params(axis='x', which='major', pad=15)

# Set x-axis limits to start from the origin
start_date = datetime(2024,1,1)
ax.set_xlim(start_date, df['overshoot_day_consumption'].max())


# Format y-axis
ax.yaxis.set_major_locator(MultipleLocator(2))
ax.grid(which='major', axis='x')


# Hide top spine
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)


# Add hover annotations using mplcursors
mplcursors.cursor(hover=True).connect(
    "add", lambda sel: sel.annotation.set_text(
        f"Country: {df.iloc[sel.target.index]['Country']}\n"
        f"Overshoot Day: {df.iloc[sel.target.index]['overshoot_day_consumption'].strftime('%d %B %Y')}\n"
        f"Number of Earths: {df.iloc[sel.target.index]['num_earths']:.2f}"
    )
)


# Display legend based on average overshoot day by region
# get legend handles and labels
handles, labels = ax.get_legend_handles_labels()

# sort legend labels based on the average overshoot day
sorted_labels = sorted(labels, key=lambda x: datetime.strptime(x.split(': ')[-1].strip(), '%d %B %Y'))
sorted_handles = [handles[labels.index(label)] for label in sorted_labels]

# Recreate legend with sorted labels and handles
legend = ax.legend(sorted_handles, sorted_labels, loc='upper center', bbox_to_anchor=(0.5, -0.2), frameon=False, ncol=2)


# save figure
fig.savefig('EarthOvershoot Days 2024 by Consumption.png', bbox_inches='tight')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 28
#      26 # Create a separate bar plot for each region:
#      27 for region, color in region_colours.items():
# ---> 28     region_data = df[df['Region'] == region]
#      29     plt.bar(region_data['overshoot_day_consumption'], region_data['num_earths'], color=color,
#      30             label=f"{region} - Overshoot Day: {region_data['overshoot_day_consumption'].mean().strftime('%d %B %Y')}")
#      33 # Titles and labels
#
# NameError: name 'df' is not defined

# %% [markdown]
# Questions to answer on the graph:
#
# - Interactive graph? Show country names on hover
# - Show the Earth Overshoot Day for 2024 for the world
# - Show the average number of Earths to show general over consumption on a planetary level (dash-dot)
# - Show grid lines for 1 number of Earth - dotted, green - same as countries from 2025
#
# - Show countries with overshoot days mid-Dec to Feb as examples?
#
# - Format axis label colours and font sizes

# %% [markdown]
# Completed
#
# - Show grid lines for year change
# - Show only x-y axis lines
# - Averge Overshoot Day and/or Number of Earths on the legend?
# - Legend to display in the order as the list, over two columns in the legend box

# %% [markdown]
# Other visualisation tools
# * try Plotly instead of Matplotlib?
# * create dashboard using PyLit

# %%
# Graph of Overshoot Days by Production

import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.ticker import MultipleLocator


# Colourmap for the regions
region_colours = {
    'North America' : 'mediumseagreen',
    'Central America/Caribbean' : 'lightseagreen',
    'South America' : 'teal',
    'EU-27' : 'mediumblue',
    'Other Europe' : 'cornflowerblue',    
    'Africa' : 'maroon',
    'Middle East/Central Asia' : 'red',
    'Asia-Pacific' : 'orange'
}

# Map region names to colours
# colours = df['Region'].map(region_colours)

# Create a figure and axis
fig, ax = plt.subplots(figsize=(18,6))

# Create a separate bar plot for each region:
for region, color in region_colours.items():
    region_data = df[df['Region'] == region]
    plt.bar(region_data['overshoot_day_production'], region_data['num_earths'], color=color, 
            label=f"{region} - Overshoot Day: {region_data['overshoot_day_production'].mean().strftime('%d %B %Y')}")
    

# Titles and labels
ax.set_title("Country Overshoot Days (by Production) and Number of Earths")
ax.set_xlabel("Country Overshoot Day")
ax.set_ylabel("Number of Earths")


# Format x-axis
# Format x-axis ticks as months
ax.xaxis.set_minor_formatter(mdates.DateFormatter('%b'))

# Set x-axis tick labels to display every 2 months
ax.xaxis.set_minor_locator(mdates.MonthLocator(interval=2))

# Add ticks to indicate year changes
ax.xaxis.set_major_locator(mdates.YearLocator())

# Display minor ticks as year labels
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))

# Adjust position of year lables to be below month labels
ax.tick_params(axis='x', which='major', pad=15)

# Set x-axis limits to start from the origin
start_date = datetime(2024,1,1)
ax.set_xlim(start_date, df['overshoot_day_production'].max())


# Format y-axis
ax.yaxis.set_major_locator(MultipleLocator(2))
ax.grid(which='major', axis='x')


# Hide top spine
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Display legend based on average overshoot day by region
# get legend handles and labels
handles, labels = ax.get_legend_handles_labels()

# sort legend labels based on the average overshoot day
sorted_labels = sorted(labels, key=lambda x: datetime.strptime(x.split(': ')[-1].strip(), '%d %B %Y'))
sorted_handles = [handles[labels.index(label)] for label in sorted_labels]

# Recreate legend with sorted labels and handles
legend = ax.legend(sorted_handles, sorted_labels, loc='upper center', bbox_to_anchor=(0.5, -0.2), frameon=False, ncol=2)


# save figure
fig.savefig('EarthOvershoot Days 2024 by Production.pdf')

plt.show()

# %% [markdown]
# #### 5. What is the relationship of overshoot days with other factors in the Global Footprint Network dataset?
# - eg life expectency v overshoot
# - GDP v overshoot
# - air quality (from the exam project!) and overshoot?

# %%
df
# Out:
#                                Country Quality Score  SDGi Life Exectancy  \
# 0                          Afghanistan            3A  52.5             62
# 1                              Albania            3A  71.6             76
# 2                              Algeria            3A  71.5             76
# 3                               Angola            3A  50.9             62
# 4                  Antigua and Barbuda            2B   NaN             78
# ..                                 ...           ...   ...            ...
# 176  Venezuela, Bolivarian Republic of            3A  60.3             71
# 177                           Viet Nam            3A  72.8             74
# 178                              Yemen            3A  52.1             64
# 179                             Zambia            3A   NaN            NaN
# 180                           Zimbabwe            2A   NaN            NaN
#
#       HDI Per Capita GDP                     Region Income Group  \
# 0    0.48            NaN   Middle East/Central Asia           LI
# 1     0.8        $14,889               Other Europe           UM
# 2    0.75        $11,137                     Africa           UM
# 3    0.59         $6,304                     Africa           LM
# 4    0.79        $18,749  Central America/Caribbean           HI
# ..    ...            ...                        ...          ...
# 176  0.69            NaN              South America           UM
# 177   0.7        $11,032               Asia-Pacific           LM
# 178  0.46         $1,780   Middle East/Central Asia           LM
# 179   NaN            NaN                     Africa           LM
# 180   NaN            NaN                     Africa           LI
#
#     Population (millions)  footprint_production  footprint_consumption  \
# 0                    40.8              0.679451               0.801465
# 1                     2.9              1.626551               2.071238
# 2                    45.4              1.769579               2.222968
# 3                      35              0.598284               0.857846
# 4                     0.1              1.508591               2.936735
# ..                    ...                   ...                    ...
# 176                  29.3              2.124106               2.109537
# 177                    99              2.237806               2.432274
# 178                  31.2              0.371747               0.613258
# 179                  19.5              1.155055               1.213215
# 180                  15.3              0.941797               1.085391
#
#      Total biocapacity   Ecological (Deficit) or Reserve  num_earths  \
# 0              0.513827                             -0.3         0.5
# 1              1.176752                             -0.9         1.4
# 2              0.663375                             -1.6         1.5
# 3              1.588191                              0.7         0.6
# 4              0.917277                             -2.0         1.9
# ..                  ...                              ...         ...
# 176            2.945992                              0.8         1.4
# 177            0.795070                             -1.6         1.6
# 178            0.347502                             -0.3         0.4
# 179            1.651920                              0.4         0.8
# 180            0.631495                             -0.5         0.7
#
#      Number of Countries required official_overshoot_day  \
# 0                             1.6                    NaT
# 1                             1.8             2024-09-23
# 2                             3.4             2024-09-04
# 3                             0.5                    NaT
# 4                             3.2             2024-07-06
# ..                            ...                    ...
# 176                           0.7             2024-09-18
# 177                           3.1             2024-08-14
# 178                           1.8                    NaT
# 179                           0.7                    NaT
# 180                           1.7                    NaT
#
#     overshoot_day_consumption  difference overshoot_day_production  \
# 0                  2025-11-19         NaN               2026-03-23
# 1                  2024-09-22        -1.0               2024-12-04
# 2                  2024-09-04         0.0               2024-11-07
# 3                  2025-10-05         NaN               2026-07-11
# 4                  2024-07-06         0.0               2024-12-31
# ..                        ...         ...                      ...
# 176                2024-09-17        -1.0               2024-09-16
# 177                2024-08-14         0.0               2024-09-02
# 178                2026-06-19         NaN               2028-01-25
# 179                2025-03-30         NaN               2025-04-22
# 180                2025-05-23         NaN               2025-08-08
#
#      diff_production_consumption
# 0                            124
# 1                             73
# 2                             64
# 3                            279
# 4                            178
# ..                           ...
# 176                           -1
# 177                           19
# 178                          585
# 179                           23
# 180                           77
#
# [181 rows x 20 columns]
